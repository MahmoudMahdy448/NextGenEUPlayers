# %%
# Count rows in each season
counts = con.execute("""
    SELECT 
        'standard_stats_2023_2024' as table_name,
        COUNT(*) as row_count
    FROM raw.standard_stats_2023_2024
    UNION ALL
    SELECT 
        'standard_stats_2024_2025',
        COUNT(*)
    FROM raw.standard_stats_2024_2025
    UNION ALL
    SELECT 
        'standard_stats_2025_2026',
        COUNT(*)
    FROM raw.standard_stats_2025_2026
""").df()

counts
# Out:
#                  table_name  row_count
# 0  standard_stats_2023_2024       2966
# 1  standard_stats_2024_2025       2968
# 2  standard_stats_2025_2026       2385
